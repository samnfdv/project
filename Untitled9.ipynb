# %% [markdown]
# <a href="https://colab.research.google.com/github/samnfdv/project/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Необходимые библиотеки

# %% [markdown]
# ### Библиотеки нужные для обработки оригинального набора даннных

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Библиотка нужная для синтезированния данных

# %%
pip install sdv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.0/140.0 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 30.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.9/74.9 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.7/170.7 kB 24.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 56.7 MB/s eta 0:00:00
# ...

# %%
import sdv
from sdv.metadata import SingleTableMetadata
from sdv.single_table import TVAESynthesizer
from sdv.evaluation.single_table import evaluate_quality

# %% [markdown]
# ### Библиотеки нужные для создания модели машинного обучения

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix, precision_score, recall_score
from sklearn.metrics import f1_score, fbeta_score

# %% [markdown]
# # Работа с оригинальным набором данных

# %%
data = pd.read_csv('/content/sample_data/cancer_patient_data _sets.csv')
data
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
# Удаление столбца Index
data.drop('index', axis=1, inplace=True)

# %%
# Замена строчных значений на числовые в столбце Level
data = data.replace({'Level':{'Low': 1, 'Medium': 2, 'High': 3}})

# %%
# Тепловая ката оригинального датасета
plt.figure(figsize = (18,9))
sn.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# <ipython-input-10-dda71068d105>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(data.corr(), annot=True, cmap='coolwarm')

# %% [markdown]
# # Синтезированние данных

# %%
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(data=data)
python_dict = metadata.to_dict()
metadata.validate()

# %%
# Создание синтезатора
synthesizer2 = TVAESynthesizer(metadata,
    epochs=500,
    batch_size=200)
# Обучение синтезатора
synthesizer2.fit(data)
# Синтезированние данных на обученном синтезаторе
synthetic_data3 = synthesizer2.sample(num_rows=10000)

# %%
# Проверка качества данных
quality_report = evaluate_quality(
    real_data=data,
    synthetic_data=synthetic_data3,
    metadata=metadata)
# Out:
# Generating report ...
# ...
# (2/2) Evaluating Column Pair Trends: : 100%|██████████| 300/300 [00:11<00:00, 25.90it/s]
#
# Overall Score: 90.44%
#
# Properties:
# - Column Shapes: 95.05%
# - Column Pair Trends: 85.84%

# %%
# Терловая карта синтезированного датасета
plt.figure(figsize = (18,9))
sn.heatmap(synthetic_data3.corr(), annot=True, cmap='coolwarm')
plt.show()
# Out:
# <ipython-input-14-e6f52205da28>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sn.heatmap(synthetic_data3.corr(), annot=True, cmap='coolwarm')

# %% [markdown]
# # Обучение модели машинного обучения

# %%
# Разделение синтезированных данных на обучающую выборку и правильнве ответы для неё
# Правильные ответы:
ytrain=synthetic_data3['Level']
# Обучающая выборка:
xtrain=synthetic_data3[['Age', 'Gender', 'Air Pollution', 'Alcohol use',
       'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
       'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
       'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
       'Weight Loss', 'Shortness of Breath', 'Wheezing',
       'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
       'Dry Cough', 'Snoring']]

# %%
# Разделение оригинального датаста на входные данные для тестированния и правильные для них ответы
# Правильные ответы:
ytest= data['Level']
# Входные данные:
xtest = data[['Age', 'Gender', 'Air Pollution', 'Alcohol use',
       'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
       'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
       'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
       'Weight Loss', 'Shortness of Breath', 'Wheezing',
       'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
       'Dry Cough', 'Snoring']]

# %%
parameters_DecisionTreeClassifier = {'criterion': ['gini', 'entropy', 'log_loss'],
               'splitter' : ['best', 'random']}
clas2 = DecisionTreeClassifier()
# Создание модели GridSearchCV
clas2GCV = GridSearchCV(clas2, parameters_DecisionTreeClassifier)
# Обучение модели GridSearchCV
clas2GCV.fit(xtrain, ytrain)
# Проверка точности
y_predGridSearchCV_DTC = clas2GCV.predict(xtest)
accuracy_2GSV = accuracy_score(y_predGridSearchCV_DTC, ytest)
# Вывод наиболее подходящих параметров
clas2GCV.best_params_
# Out:
# {'criterion': 'entropy', 'splitter': 'best'}

# %%
# Создание класификатора
clas2 = DecisionTreeClassifier(criterion='gini', splitter='random')
# Обучение класификатора
clas2.fit(xtrain, ytrain)
# Тестирование класификатора
y_pred_DecisionTreeClassifier = clas2.predict(xtest)
# Провеерки точности класификатора
accuracy_DecisionTreeClassifier = accuracy_score(y_pred_DecisionTreeClassifier, ytest)
print('Точность модели Дерево решений =', accuracy_DecisionTreeClassifier)
print('Матрица ошибок для модели дерево решений:',confusion_matrix(ytest, y_pred_DecisionTreeClassifier), sep='\n')
print('Мера F1_score для модели Дерево решений:', f1_score(ytest, y_pred_DecisionTreeClassifier, average='weighted'))
# Out:
# Точность модели Дерево решений = 0.986
# Матрица ошибок для модели дерево решений:
# [[302   1   0]
#  [ 13 319   0]
#  [  0   0 365]]
# Мера F1_score для модели Дерево решений: 0.9860070879742688
